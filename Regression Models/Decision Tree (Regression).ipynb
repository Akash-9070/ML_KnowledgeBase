# %%
from IPython.display import Image,display,HTML
Image(filename=r"C:\Users\AKASH\Pictures\Screenshots\table.jpg",width=800,height=600)

# %% [markdown]
# Decision Tree -- Regression ==> lets discuss some theory about it
#
# > Decision Tree are also capable of performing regression tasks
# > <b>
#   The main diffrence is Instead of predicting the Class in each node , it predicts a value
#   For example suppose you want to make predictions on the new insatnce X1 = 0.6 .You traverse
#   the tree starting at the root , and you eventualy reach the leaf node that predicts the (value = 0.1106)
#   ..This prediction is simply the average target value of the 110 training instances associated with the node </b>
#
# > This prediction results in a Mean squared Error (MSE) equals to 0.0151  over 110 instances

# %%
Image(filename=r"C:\Users\AKASH\Pictures\Screenshots\decision.png",width=800,height=600)
# This prediction is simply the average target value of the 110 training instances associated with the node

# %%
# Display the first image
display(Image(filename=r"C:\Users\AKASH\Pictures\Screenshots\decision2.png", width=800, height=600))

# Display the second image
display(Image(filename=r"C:\Users\AKASH\Pictures\Screenshots\table2.png", width=800, height=600))

# %% [raw]
# It is said in the tutorial that decision tree are not that much good with the small datasets

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\AKASH\Desktop\ML\Machine Learning A-Z (Codes and Datasets)\Regression\Section 8 - Decision Tree Regression\Python\Position_Salaries.csv")

# %%
data
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
X = data["Level"].values.reshape(-1,1)
y = data["Salary"].values.reshape(-1,1)

# No featuer scaling is needed in Decision tree

# %%
# Training the Decision Tree Regression model on the whole datasets
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
# Predicting a new result
regressor.predict([[6.5]])
# Out:
# array([150000.])

# %%
# Visualising the Decision Tree Regression results (higher resolution)
X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('Truth or Bluff (Decision Tree Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# #  we can clearly see that the predictions are not that good ..... as mentioned earlier that decision tree is not the best algorithm for single feature datasets

# %% [markdown]
# # It performs better with multifeature
