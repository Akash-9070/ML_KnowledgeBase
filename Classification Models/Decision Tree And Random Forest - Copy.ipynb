# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import seaborn as sns 
# %matplotlib inline

# %%
df = pd.read_csv("Desktop/Py_DS_ML_Bootcamp-master/Refactored_Py_DS_ML_Bootcamp-master/15-Decision-Trees-and-Random-Forests/kyphosis.csv")

# %%
df.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
# df["Kyphosis"] = df["Kyphosis"].replace({"absent": 0, "present": 1})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %%
sns.pairplot(df,hue="Kyphosis")
# Out:
# C:\Users\AKASH\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop("Kyphosis",axis=1)

# %%
y = df["Kyphosis"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
prediction = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,prediction))
print(classification_report(y_test,prediction))
# Out:
# [[15  2]
#  [ 5  3]]
#               precision    recall  f1-score   support
#
#       absent       0.75      0.88      0.81        17
#      present       0.60      0.38      0.46         8
#
#     accuracy                           0.72        25
#    macro avg       0.68      0.63      0.64        25
# weighted avg       0.70      0.72      0.70        25

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=200)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(confusion_matrix(y_test,rfc_pred))
print(classification_report(y_test,rfc_pred))
# Out:
# [[17  0]
#  [ 5  3]]
#               precision    recall  f1-score   support
#
#       absent       0.77      1.00      0.87        17
#      present       1.00      0.38      0.55         8
#
#     accuracy                           0.80        25
#    macro avg       0.89      0.69      0.71        25
# weighted avg       0.85      0.80      0.77        25

# %%
# random forset will always going to do good if the data
# set if bigger
