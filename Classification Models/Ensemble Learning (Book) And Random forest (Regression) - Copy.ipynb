# %% [raw]
# >>  Suppose you ask a complex question to thousands of random people, then aggregate
#     their answers. In many cases you will find that this aggregated answer is better than
#     an expert’s answer. This is called the wisdom of the crowd. Similarly, if you aggregate
#     the predictions of a group of predictors (such as classifiers or regressors), you will
#     often get better predictions than with the best individual predictor. A group of pre‐
#     dictors is called an ensemble; thus, this technique is called Ensemble Learning, and an
#     Ensemble Learning algorithm is called an Ensemble method.
#
# >>  you can train a group of Decision Tree classifiers, each on a different
#     random subset of the training set. To make predictions, you just obtain the predic‐
#     tions of all individual trees, then predict the class that gets the most votes
#
# >>  Such an ensemble of Decision Trees is called a Random Forest,
#     and despite its simplicity, this is one of the most powerful Machine Learning algo‐
#     rithms available today

# %%
# In this notebook we will discuss the most popular Ensemble methods including baging ,boosting ,stacking 
#  we will also discuss randomforest at the end

# %% [markdown]
# # Voting Classifiers

# %%
from IPython.display import Image
# Display the first image
display(Image(filename=r"C:\Users\AKASH\Pictures\Screenshots\voting1.png", width=800, height=600))
# Display the second image
display(Image(filename=r"C:\Users\AKASH\Pictures\Screenshots\voting2.png", width=800, height=600))

# %% [raw]
# The following code creates and trains a voting classifier in Scikit-Learn, composed of
# three diverse classifiers

# %% [raw]
# from sklearn.ensemble import RandomForestClassifier, VotingClassifier
# from sklearn.linear_model import LogisticRegression
# from sklearn.naive_bayes import GaussianNB
# from sklearn.svm import SVC
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.tree import DecisionTreeClassifier  # Import Decision Tree classifier
# from sklearn.metrics import accuracy_score
#
# # Initialize classifiers
# log_clf = LogisticRegression()
# rnd_clf = RandomForestClassifier()
# svm_clf = SVC()
# nb_clf = GaussianNB()
# knn_clf = KNeighborsClassifier()
# dt_clf = DecisionTreeClassifier()  # Decision Tree classifier
#
# # Initialize Voting Classifier with all classifiers
# voting_clf = VotingClassifier(estimators=[
#     ("lr", log_clf),
#     ("rf", rnd_clf),
#     ("svc", svm_clf),
#     ("nb", nb_clf),
#     ("knn", knn_clf),
#     ("dt", dt_clf)  # Add Decision Tree classifier
# ], voting="hard")
#
# # Fit the voting classifier with training data
# voting_clf.fit(X_train, y_train)
#
#
# voting_predictions = voting_clf.predict(test)
#
# voting_predictions

# %% [raw]
# LogisticRegression 0.864
# RandomForestClassifier 0.896
# SVC 0.888
# VotingClassifier 0.904
# # here we can see that the voting classifier slightly outperform all the individual classifiers

# %% [markdown]
# # Random Forest Regression

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
dataset = pd.read_csv(r"C:\Users\AKASH\Desktop\ML\Machine Learning A-Z (Codes and Datasets)\Regression\Section 8 - Decision Tree Regression\Python\Position_Salaries.csv")
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %%
# Training the Random Forest Regression model on the whole dataset
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X, y)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
# Predicting a new result
regressor.predict([[6.5]])
# Out:
# array([167000.])

# %%
# Visualising the Random Forest Regression results (higher resolution)
X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('Truth or Bluff (Random Forest Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# These are better predictions then the decision tree ,,,
#
# While Random Forest is often known to perform better than a single Decision Tree in many scenarios...
